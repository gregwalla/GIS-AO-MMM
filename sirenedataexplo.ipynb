# %%
import pandas as pd
import geopandas as gpd
from pathlib import Path

# %%
 
 datas = {"sirene": Path(r"C:\Users\J0102113\Documents\a-SIGetWeb\AO\mul\datas\m2a_base-sirene-v3-consolidee-insee.geojson") }
 #cities  = {'Mulhouse' : ( 7.3359, 47.7508)}

# %%
cols = [ 
     'codepostaletablissement',  'codecommuneetablissement',
    'activiteprincipaleetablissement', 'classeetablissement', 'geometry'
    ]

# %%
filename = datas["sirene"]
file = open(filename)
gdf = gpd.read_file(file)

# %%
pd.set_option('display.max_columns', None)

# %%
gdf.head()
# Out:
#   libellecedexetablissement codecedexetablissement  \
# 0                      None                   None
# 1                      None                   None
# 2                      None                   None
# 3                      None                   None
# 4                      None                   None
#
#   libellecommuneetablissement anneecategorieentreprise  \
# 0                    HABSHEIM                     2019
# 1                    MULHOUSE                     2019
# 2                    MULHOUSE                     None
# 3                 WITTELSHEIM                     2019
# 4                    MULHOUSE                     2019
#
#   libellevoieetablissement categorieentreprise  \
# 0         D ESCHENTZWILLER                 PME
# 1                  NEPPERT                 PME
# 2          ARISTIDE BRIAND                None
# 3               DES TUILES                 PME
# 4            DE WESSERLING                 PME
#
# ...

# %%
gdf2.columns
# Out:
# Index(['libellecommuneetablissement', 'anneecategorieentreprise',
#        'libellevoieetablissement', 'categorieentreprise',
#        'etatadministratifunitelegale', 'numerovoieetablissement',
#        'typevoieetablissement', 'siretsiegeunitelegale',
#        'statutdiffusionetablissement', 'siret', 'etablissementsiege', 'nic',
#        'siren', 'codedepartementetablissement',
#        'codearrondissementetablissement', 'nombreperiodesunitelegale',
#        'statutdiffusionunitelegale', 'naturejuridiqueunitelegale',
#        'caractereemployeuretablissement', 'classeunitelegale',
#        'adresseetablissement', 'soussectionunitelegale', 'sectionunitelegale',
#        'nomenclatureactiviteprincipaleetablissement', 'groupeunitelegale',
#        'activiteprincipaleetablissement', 'divisionunitelegale',
#        'codecommuneetablissement', 'codepostaletablissement',
#        'nombreperiodesetablissement', 'classeetablissement',
# ...

# %%
gdf2.head()
# Out:
#   libellecommuneetablissement anneecategorieentreprise  \
# 0                    HABSHEIM                     2019
# 1                    MULHOUSE                     2019
# 2                    MULHOUSE                     None
# 3                 WITTELSHEIM                     2019
# 4                    MULHOUSE                     2019
#
#   libellevoieetablissement categorieentreprise etatadministratifunitelegale  \
# 0         D ESCHENTZWILLER                 PME                       Active
# 1                  NEPPERT                 PME                       Active
# 2          ARISTIDE BRIAND                None                       Active
# 3               DES TUILES                 PME                       Active
# 4            DE WESSERLING                 PME                       Active
#
#   numerovoieetablissement typevoieetablissement siretsiegeunitelegale  \
# 0                       1                   Rue        80457357400022
# ...
